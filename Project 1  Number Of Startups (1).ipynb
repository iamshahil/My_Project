# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor

# %%
data=pd.read_csv(r"C:\Users\Power User\Downloads\indian_startups_by_state.csv")
data
# Out:
#       S No.  Year                        State  \
# 0         1  2023  Andaman and Nicobar Islands
# 1         2  2023  Andaman and Nicobar Islands
# 2         3  2023  Andaman and Nicobar Islands
# 3         4  2023  Andaman and Nicobar Islands
# 4         5  2023  Andaman and Nicobar Islands
# ...     ...   ...                          ...
# 7086   7087  2016                   Tamil Nadu
# 7087   7088  2016                    Telangana
# 7088   7089  2016                Uttar Pradesh
# 7089   7090  2016                  Uttarakhand
# 7090   7091  2016                  West Bengal
#
#                                  Industry  Count          Last Update
# 0     AR VR (Augmented + Virtual Reality)      2  18-06-2023 04:00:02
# 1                              Automotive      1  18-06-2023 04:00:02
# 2                            Construction      2  18-06-2023 04:00:02
# 3                             IT Services      1  18-06-2023 04:00:02
# 4                        Travel & Tourism      1  18-06-2023 04:00:02
# ...                                   ...    ...                  ...
# 7086                        NOT SPECIFIED     55  18-06-2023 04:00:02
# 7087                        NOT SPECIFIED     20  18-06-2023 04:00:02
# 7088                        NOT SPECIFIED     29  18-06-2023 04:00:02
# 7089                        NOT SPECIFIED      4  18-06-2023 04:00:02
# 7090                        NOT SPECIFIED      8  18-06-2023 04:00:02
#
# [7091 rows x 6 columns]

# %%
data.drop(["S No.","Last Update"],axis=1,inplace=True)
data
# Out:
#       Year                        State                             Industry  \
# 0     2023  Andaman and Nicobar Islands  AR VR (Augmented + Virtual Reality)
# 1     2023  Andaman and Nicobar Islands                           Automotive
# 2     2023  Andaman and Nicobar Islands                         Construction
# 3     2023  Andaman and Nicobar Islands                          IT Services
# 4     2023  Andaman and Nicobar Islands                     Travel & Tourism
# ...    ...                          ...                                  ...
# 7086  2016                   Tamil Nadu                        NOT SPECIFIED
# 7087  2016                    Telangana                        NOT SPECIFIED
# 7088  2016                Uttar Pradesh                        NOT SPECIFIED
# 7089  2016                  Uttarakhand                        NOT SPECIFIED
# 7090  2016                  West Bengal                        NOT SPECIFIED
#
#       Count
# 0         2
# 1         1
# 2         2
# 3         1
# 4         1
# ...     ...
# 7086     55
# 7087     20
# 7088     29
# 7089      4
# 7090      8
#
# [7091 rows x 4 columns]

# %%
data["State"].unique()
# Out:
# array(['Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra and Nagar Haveli and Daman and Diu',
#        'Delhi', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jammu and Kashmir', 'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh',
#        'Lakshadweep', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Puducherry',
#        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana',
#        'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal',
#        'NOT SPECIFIED'], dtype=object)

# %%
ob1=LabelEncoder()
ob2=LabelEncoder()

# %%
data["State"]=ob1.fit_transform(data["State"])
data["Industry"]=ob2.fit_transform(data["Industry"])
data
# Out:
#       Year  State  Industry  Count
# 0     2023      0         1      2
# 1     2023      0        10      1
# 2     2023      0        14      2
# 3     2023      0        27      1
# 4     2023      0        55      1
# ...    ...    ...       ...    ...
# 7086  2016     31        33     55
# 7087  2016     32        33     20
# 7088  2016     34        33     29
# 7089  2016     35        33      4
# 7090  2016     36        33      8
#
# [7091 rows x 4 columns]

# %%
x=data.drop(["Count"],axis=1)
y=data["Count"]

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=9)

# %%
len(xtest)
# Out:
# 1419

# %% [markdown]
# ## Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model4=RandomForestRegressor()
model4.fit(xtrain,ytrain)
# Out:
# RandomForestRegressor()

# %%
print(model4.score(xtrain,ytrain))
print(model4.score(xtest,ytest))
# Out:
# 0.9637899878784897
# 0.8173209252503348

# %%
model4.predict([[2023,0,27]])
# Out:
# array([6.2])

# %%
import numpy as np

year = int(input("year"))
state = input("state")
state = ob1.transform([state])

industry = input("industry")
industry = ob2.transform([industry])
print("Transformed state shape:", state.shape)
print("Transformed industry shape:", industry.shape)
user_input = np.array([[year, *state, *industry]])
print("User input shape:", user_input.shape)

prediction = model4.predict(user_input)
print("Prediction:", int(prediction))
# Out:
# year 2023
# state Kerala
# industry IT Services
# Transformed state shape: (1,)
# Transformed industry shape: (1,)
# User input shape: (1, 3)
# Prediction: 117

# %% [markdown]
# ## Decision Tree Regressor

# %%
model=DecisionTreeRegressor()
model.fit(xtrain,ytrain)
# Out:
# DecisionTreeRegressor()

# %%
print(model.score(xtrain,ytrain))
print(model.score(xtest,ytest))
# Out:
# 1.0
# 0.7667773470494103

# %%
model.predict([[2023,16,27]])
# Out:
# array([102.])

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
model2=LinearRegression()
model2.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
print(model2.score(xtrain,ytrain))
print(model2.score(xtest,ytest))
# Out:
# 0.01600086421941227
# 0.016177561906170368

# %% [markdown]
# ## Support Vector Regression

# %%
from sklearn.svm import SVR

# %%
model3=SVR()
model3.fit(xtrain,ytrain)
# Out:
# SVR()

# %%
print(model3.score(xtrain,ytrain))
print(model3.score(xtest,ytest))
# Out:
# -0.11037602412472602
# -0.09764600550919544

# %% [markdown]
# ## Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model4=RandomForestRegressor()
model4.fit(xtrain,ytrain)
# Out:
# RandomForestRegressor()

# %%
print(model4.score(xtrain,ytrain))
print(model4.score(xtest,ytest))
# Out:
# 0.9639328921691711
# 0.8052950583360934

# %%
model.predict([[2023,16,27]])
# Out:
# array([102.])

# %% [markdown]
# ## Gradient Boosting Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
model5=GradientBoostingRegressor()
model5.fit(xtrain,ytrain)
# Out:
# GradientBoostingRegressor()

# %%
print(model5.score(xtrain,ytrain))
print(model5.score(xtest,ytest))
# Out:
# 0.4319823980688956
# 0.3998940538780268

# %% [markdown]
# ## KNeighborsRegressor

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
model6=KNeighborsRegressor()
model6.fit(xtrain,ytrain)
# Out:
# KNeighborsRegressor()

# %%
print(model6.score(xtrain,ytrain))
print(model6.score(xtest,ytest))
# Out:
# 0.5627474516002124
# 0.3591744990506349

# %% [markdown]
# # Build Gradio App

# %%
# !pip3 install gradio
# Out:
# Requirement already satisfied: gradio in c:\users\power user\anaconda3\lib\site-packages (5.28.0)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in c:\users\power user\anaconda3\lib\site-packages (from gradio) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\power user\anaconda3\lib\site-packages (from gradio) (4.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\power user\anaconda3\lib\site-packages (from gradio) (0.115.8)
# Requirement already satisfied: ffmpy in c:\users\power user\anaconda3\lib\site-packages (from gradio) (0.5.0)
# Requirement already satisfied: gradio-client==1.10.0 in c:\users\power user\anaconda3\lib\site-packages (from gradio) (1.10.0)
# Requirement already satisfied: groovy~=0.1 in c:\users\power user\anaconda3\lib\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\power user\anaconda3\lib\site-packages (from gradio) (0.27.0)
# Requirement already satisfied: huggingface-hub>=0.28.1 in c:\users\power user\anaconda3\lib\site-packages (from gradio) (0.28.1)
# Requirement already satisfied: jinja2<4.0 in c:\users\power user\anaconda3\lib\site-packages (from gradio) (3.1.4)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\power user\anaconda3\lib\site-packages (from gradio) (2.1.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\power user\anaconda3\lib\site-packages (from gradio) (1.26.3)
# Requirement already satisfied: orjson~=3.0 in c:\users\power user\anaconda3\lib\site-packages (from gradio) (3.10.15)
# Requirement already satisfied: packaging in c:\users\power user\anaconda3\lib\site-packages (from gradio) (24.1)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\power user\anaconda3\lib\site-packages (from gradio) (2.2.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in c:\users\power user\anaconda3\lib\site-packages (from gradio) (10.4.0)
# Requirement already satisfied: pydantic<2.12,>=2.0 in c:\users\power user\anaconda3\lib\site-packages (from gradio) (2.8.2)
# Requirement already satisfied: pydub in c:\users\power user\anaconda3\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in c:\users\power user\anaconda3\lib\site-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\power user\anaconda3\lib\site-packages (from gradio) (6.0.1)
# Requirement already satisfied: ruff>=0.9.3 in c:\users\power user\anaconda3\lib\site-packages (from gradio) (0.9.6)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in c:\users\power user\anaconda3\lib\site-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\power user\anaconda3\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\users\power user\anaconda3\lib\site-packages (from gradio) (0.45.3)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in c:\users\power user\anaconda3\lib\site-packages (from gradio) (0.13.2)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\power user\anaconda3\lib\site-packages (from gradio) (0.15.1)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\power user\anaconda3\lib\site-packages (from gradio) (4.11.0)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\power user\anaconda3\lib\site-packages (from gradio) (0.34.0)
# Requirement already satisfied: fsspec in c:\users\power user\anaconda3\lib\site-packages (from gradio-client==1.10.0->gradio) (2024.6.1)
# Requirement already satisfied: websockets<16.0,>=10.0 in c:\users\power user\anaconda3\lib\site-packages (from gradio-client==1.10.0->gradio) (14.2)
# Requirement already satisfied: idna>=2.8 in c:\users\power user\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\power user\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Requirement already satisfied: certifi in c:\users\power user\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\power user\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\power user\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in c:\users\power user\anaconda3\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (3.13.1)
# Requirement already satisfied: requests in c:\users\power user\anaconda3\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\power user\anaconda3\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (4.66.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\power user\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\power user\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\power user\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\power user\anaconda3\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\power user\anaconda3\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (2.20.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\power user\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\power user\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\power user\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.7.1)
# Requirement already satisfied: colorama in c:\users\power user\anaconda3\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\power user\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\power user\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\power user\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.15.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\power user\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.28.1->gradio) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\power user\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.28.1->gradio) (2.2.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\power user\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.0)

# %%
def fun(year,state,industry):
    state_encoded = ob1.transform([state])
    industry_encoded = ob2.transform([industry])
    pred = model4.predict([[year,state_encoded[0],industry_encoded[0]]])
    return int(pred)
        
fun(2023,"Kerala","IT Services")
# Out:
# 131

# %%
import gradio as gr

# %%
headline ="Number of startups App"
iface = gr.Interface(fn=fun,inputs=[
        gr.Number(label="year"),
        gr.Textbox(label="state"),
        gr.Textbox(label="industry")],
        outputs=[gr.Textbox(label="Startups Count")],title=headline)
iface.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7867
#
# Could not create share link. Please check your internet connection or our status page: https://status.gradio.app.
# <div><iframe src="http://127.0.0.1:7867/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
